# %% [markdown]
# ###### 16 luty
#
# ### Neural Networks & Deep Learning

# %% [markdown]
# PLAN ZAJĘĆ
# Podstawy sieci neuronowych
#    - Neuron i rodzaje sieci neuronoych
#    - Rodzaje zastosowań
#    - Sposoby uczenia - od kuchni
#
#    * sieć neuronowa zazwyczaj podaje informację niepewną.
#    * google translate (sieci bayesowskie)
#
# Głębokie sieci
#     - warstwy sieci neuronowych
#
# Coś tam jeszcze

# %% [markdown]
# ### Neuron i rodzaje sieci neuronowych
# ![Zrzut ekranu 2020-02-16 o 09.27.07.png](attachment:Zrzut ekranu 2020-02-16 o 09.27.07.png)

# %% [markdown]
# Wejście -> wyjście. Po drodze robimy sumę i pewną funkcję sumy

# %% [markdown]
# - Percepton wielowarstwowy (jesli warstw ukrytych jest więcej niż 2 to jest to uczenie głębokie)

# %% [markdown]
# Piaskownica: playground.tensorflow.org

# %% [markdown]
# Wytłumaczenie przykładu z tensorflow
#
# 1) [-1,-1] [0,1]  ## gdzie [-1,-1] oznacza bierzemy kulke z współrzędnymi -1,-1
# 2)

# %% [markdown]
# ![Zrzut ekranu 2020-02-16 o 09.44.28.png](attachment:Zrzut ekranu 2020-02-16 o 09.44.28.png)

# %% [markdown]
# Jeden punkt rozbijamy na dwie cechy, x1 oraz x2

# %% [markdown]
# Mówiliśmy o:
#     - funkcja aktywacji
#
#     - pochodna
#
#     - ReLu
#
#     - sieć jednokierunkowa
#
#     - sieć rekurencyjna
#
#     - regresja (pokazuje trend)
#
#     - klasyfikacja
#
#     - klasyfikacja i klasteryzacja (przypisanie do pewnej klasy/do określonej kategorii a stworzenie klas od zera/czyli przypisane do grup o wspólnych cechach)
